# %%
with open('032 rosalind_tree.txt', 'r') as f:
     data = f.read()
f.closed
data
# Out:
# True
# ...

# %%
n = data.splitlines()[0]
s = data.splitlines()[1:]

# %%
n
len(s)
# Out:
# '925'
# 854

# %%
925-1-854
# Out:
# 70
